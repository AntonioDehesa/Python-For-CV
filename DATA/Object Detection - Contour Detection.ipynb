# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('DATA/internal_external.png',0)
img.shape
# Out:
# (652, 1080)

# %%
plt.imshow(img,cmap='gray')

# %%
image, contours, hierarchy = cv2.findContours(img, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)

# %%
type(contours)
# Out:
# list

# %%
type(image)
# Out:
# numpy.ndarray

# %%
type(hierarchy)
# Out:
# numpy.ndarray

# %%
external_contours = np.zeros(image.shape)

# %%
for i in range(len(contours)):
    if hierarchy[0][i][3] == -1: #external
        cv2.drawContours(external_contours, contours, i, 255, -1)

# %%
plt.imshow(external_contours)

# %%
internal_contours = np.zeros(image.shape)
for i in range(len(contours)):
    if hierarchy[0][i][3] != -1: #internal
        cv2.drawContours(internal_contours, contours, i, 255, -1)

# %%
plt.imshow(internal_contours)

# %%
full_image = cv2.addWeighted(external_contours, 0.5, internal_contours, 0.5, 0)

# %%
plt.imshow(full_image)
