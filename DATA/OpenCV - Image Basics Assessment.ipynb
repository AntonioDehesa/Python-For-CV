# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image_name = "dog_backpack.jpg"

# %%
img_org = cv2.imread("DATA/{}".format(image_name))

# %%
type(img_org)
# Out:
# numpy.ndarray

# %%
plt.imshow(img_org)

# %%
img_fix = cv2.cvtColor(img_org, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_fix)

# %%
plt.imshow(cv2.flip(img_fix,0))

# %%
img_redRectangle = img_fix

# %%
cv2.rectangle(img=img_redRectangle, pt1=(400,250), pt2=(550,550), color=(255,0,0), thickness=10)
# Out:
# array([[[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        ...,
#
#        [[ 49,  41,  38],
#         [ 51,  39,  39],
#         [ 53,  37,  38],
#         ...,
#         [ 75,  80,  86],
#         [ 72,  77,  83],
#         [ 70,  75,  79]],
#
#        [[ 50,  42,  39],
#         [ 52,  40,  40],
#         [ 53,  37,  38],
#         ...,
#         [ 75,  82,  88],
#         [ 73,  78,  84],
#         [ 70,  75,  79]],
#
#        [[ 51,  43,  40],
#         [ 51,  39,  39],
#         [ 54,  38,  39],
# ...

# %%
plt.imshow(img_fix)

# %%
#Lol, i messed up

# %%
img_fix = cv2.cvtColor(img_org, cv2.COLOR_BGR2RGB)

# %%
cv2.rectangle(img=img_redRectangle, pt1=(250,400), pt2=(600,650), color=(255,0,0), thickness=15)
# Out:
# array([[[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        ...,
#
#        [[ 49,  41,  38],
#         [ 51,  39,  39],
#         [ 53,  37,  38],
#         ...,
#         [ 75,  80,  86],
#         [ 72,  77,  83],
#         [ 70,  75,  79]],
#
#        [[ 50,  42,  39],
#         [ 52,  40,  40],
#         [ 53,  37,  38],
#         ...,
#         [ 75,  82,  88],
#         [ 73,  78,  84],
#         [ 70,  75,  79]],
#
#        [[ 51,  43,  40],
#         [ 51,  39,  39],
#         [ 54,  38,  39],
# ...

# %%
plt.imshow(img_fix)

# %%
plt.imshow(img_redRectangle)

# %%
#Messed up several times, but there it is

# %%
img_triangle = img_fix

# %%
cv2.line(img_triangle, pt1=(250,600), pt2=(300, 400), color=(0,255,0), thickness=10)
cv2.line(img_triangle, pt1=(300,400), pt2=(550, 700), color=(0,255,0), thickness=10)
cv2.line(img_triangle, pt1=(550,700), pt2=(250, 600), color=(0,255,0), thickness=10)
# Out:
# array([[[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        ...,
#
#        [[ 49,  41,  38],
#         [ 51,  39,  39],
#         [ 53,  37,  38],
#         ...,
#         [ 75,  80,  86],
#         [ 72,  77,  83],
#         [ 70,  75,  79]],
#
#        [[ 50,  42,  39],
#         [ 52,  40,  40],
#         [ 53,  37,  38],
#         ...,
#         [ 75,  82,  88],
#         [ 73,  78,  84],
#         [ 70,  75,  79]],
#
#        [[ 51,  43,  40],
#         [ 51,  39,  39],
#         [ 54,  38,  39],
# ...

# %%
plt.imshow(img_triangle)

# %%
img_tri = img_fix

# %%
pts = np.array([[250,600], [350,400], [550,600]], np.int32)

# %%
isClosed = True

# %%
pts = pts.reshape((-1, 1, 2))

# %%
color = (255, 0, 0) 
img_tri = cv2.polylines(img_tri, [pts],isClosed, color, thickness=20)

# %%
plt.imshow(img_tri)

# %%
#two methods. With only lines, or with polyline. To fill it, we just use fillpoly instead

# %%
img_tri = cv2.fillPoly(img_tri, [pts],isClosed, color, thickness=-1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-19261ff6bd32> in <module>
# ----> 1 img_tri = cv2.fillPoly(img_tri, [pts],isClosed, color, thickness=-1)
#
# TypeError: an integer is required (got type tuple)

# %%
img_tri = cv2.fillPoly(img_fix, [pts], color)

# %%
plt.imshow(img_tri)

# %%
import cv2
import numpy as np
def createCircle(event, x, y, flag, param):
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img, (x,y), 100, (0,0,255), thickness=10)

img = cv2.imread("DATA/dog_backpack.jpg")
cv2.namedWindow(winname = "Dog")
cv2.setMouseCallback("Dog", createCircle)

while True: 
    cv2.imshow("Dog", img)
    if cv2.waitKey(20) & 0xFF == 27:
        break
cv2.destroyAllWindows()
